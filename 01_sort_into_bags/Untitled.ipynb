# %%
import glob
import os
import numpy as np
from scipy.stats import norm
import imageio
import pandas as pd

# %%
vid_train_path = r'../../data/commaai/destination/'
filepath = r'../../data/commaai/destination/'

# %%
test_filenames = np.load('test_files_run2.npy', allow_pickle = True)

# %%
yaw_path = '../../data/commaai/training_files/unrestricted_gauss_dens_resampled/yaws.csv'

# %%
df = pd.read_csv(yaw_path, header =None)
df.columns = ['angle']

# %%
df
# Out:
#        angle
# 0       -0.2
# 1        7.6
# 2      -10.5
# 3       10.5
# 4       23.7
# ...      ...
# 93004   -7.6
# 93005    8.2
# 93006   -6.1
# 93007   -6.7
# 93008    6.7
#
# [93009 rows x 1 columns]

# %%
df.to_csv('yaws_unrestricted_gauss_dens_resampled.csv')

# %%
train_set_size = 1500
test_set_size = 500

# read names of all video files
all_vid_files = glob.glob(os.path.join(vid_train_path, "*.hevc")) 

# choose files for train and test set
test_files_vid = all_vid_files[-test_set_size:]
train_files_vid = all_vid_files[:train_set_size]

# get filenames without ending
train_filenames = [os.path.basename(train_files_vid[i])[:-5] for i in range(0, len(train_files_vid))]
test_filenames = [os.path.basename(test_files_vid[i])[:-5] for i in range(0, len(test_files_vid))]

train_vid_files = [str(filepath + train_filenames[i] + '.hevc') for i in range(len(train_filenames))]
train_yaw_files = [str(filepath + train_filenames[i] + '.value') for i in range(len(train_filenames))]
train_time_files = [str(filepath + train_filenames[i] + '.t') for i in range(len(train_filenames))]

density_path = '../../data/commaai/density/densityfastkde_density.csv'
density = pd.read_csv(density_path)

# %%
def read_vid_angles(vid_path, value_path, t_path, density):
    
    # read video
    vid = imageio.get_reader(vid_path,  'ffmpeg')
    frames = np.array([im for im in vid.iter_data()], dtype=np.uint8)
    vid.close()
    
    # read steering angles
    angle = np.load(value_path)
    
    # read device boot time
    t = np.load(t_path)
    
    # dataframe of angles and timestamps
    angles = pd.DataFrame({'t' : t, 'angle': angle})
    
    # get timestamps of frames
    timestamps_frames = np.zeros(frames.shape[0])
    start_stamp = t[0] 
    timestamps_frames[0] = start_stamp
    for i in range(1, len(timestamps_frames)):
        timestamps_frames[i] = timestamps_frames[i - 1] + 0.05
    
    # get angles per frame
    target_angles = [angles.loc[find_closest_element(timestamps_frames[i], np.array(angles['t'])),'angle'] for i in range(0, len(timestamps_frames))]
    
    # downsamples images
    new_height = 174
    new_width = 131
    rez_frames = []
    for i in range(0, frames.shape[0]):
        frames_i = cv2.resize(frames[i, :, :, :], dsize = (new_height,new_width), interpolation = cv2.BILINEAR)
        rez_frames.append(frames_i)
    frames_i = np.array(frames_i)
    # return every 5th frame
    print(len(rez_frames))
    trans_label = [norm.ppf(Fy(target_angles[i], density)) for i in range(0, len(target_angles))]
    
    return(rez_frames[::5], target_angles[::5], trans_label)

def find_closest_element(y: float, arr: np.ndarray):
    index = np.searchsorted(arr,y)
    if (index >= 1) & (index < arr.shape[0]):
        res = [arr[index - 1], arr[index]]
    elif (index < arr.shape[0]):
        return np.array(index)
    else:
        return np.array(index - 1)

    if res[0] == res[1]:
        return np.array(index - 1)
    else:
        diff_pre = np.abs(y-res[0])
        diff_aft = np.abs(y-res[1])
        if diff_pre == diff_aft:
            return np.array(index - 1), 
        else:
            return index - 1 if diff_pre < diff_aft else index

# %%
for i in range(0, len(train_vid_files)):
    # get single file
    video_file = train_vid_files[i]
    angle_file = train_yaw_files[i]
    time_file = train_time_files[i]
    
    images, yaw, trans_label = read_vid_angles(video_file, angle_file, time_file, density)
    
    for i, (img, label, tr_label) in enumerate(zip(images, yaw, trans_label)):
        
        if abs(label) <= 10:
            path = '../../data/commaai/train_bags/1/'
            filename = str(path + str(i))
            np.save(filename, np.array(img, label, tr_label))
        
        elif abs(label) <= 20 and abs(label) > 10:
            path = '../../data/commaai/train_bags/2/'
            filename = str(path + str(i))
            np.save(filename, np.array(img, label, tr_label))
        
        elif abs(label) <= 30 and abs(label) > 20:
            path = '../../data/commaai/train_bags/3/'
            filename = str(path + str(i))
            np.save(filename, np.array(img, label, tr_label))
        
        elif abs(label) <= 40 and abs(label) > 30:
            path = '../../data/commaai/train_bags/4/'
            filename = str(path + str(i))
            np.save(filename, np.array(img, label, tr_label))
        
        elif abs(label) <= 50 and abs(label) > 40:
            path = '../../data/commaai/train_bags/5/'
            filename = str(path + str(i))
            np.save(filename, np.array(img, label, tr_label))
        
        elif abs(label) <= 60 and abs(label) > 70:
            path = '../../data/commaai/train_bags/6/'
            filename = str(path + str(i))
            np.save(filename, np.array(img, label, tr_label))
        
        elif abs(label) <= 80 and abs(label) > 70:
            path = '../../data/commaai/train_bags/7/'
            filename = str(path + str(i))
            np.save(filename, np.array(img, label, tr_label))
        
        elif abs(label) <= 90 and abs(label) > 80:
            path = '../../data/commaai/train_bags/8/'
            filename = str(path + str(i))
            np.save(filename, np.array(img, label, tr_label))
        
        elif abs(label) <= 100 and abs(label) > 90:
            path = '../../data/commaai/train_bags/9/'
            filename = str(path + str(i))
            np.save(filename, np.array(img, label, tr_label))
        
        elif abs(label) <= 100 and abs(label) > 90:
            path = '../../data/commaai/train_bags/10/'
            filename = str(path + str(i))
            np.save(filename, np.array(img, label, tr_label))
       
        elif abs(label) <= 110 and abs(label) > 100:
            path = '../../data/commaai/train_bags/11/'
            filename = str(path + str(i))
            np.save(filename, np.array(img, label, tr_label))
        
        elif abs(label) <= 120 and abs(label) > 110:
            path = '../../data/commaai/train_bags/12/'
            filename = str(path + str(i))
            np.save(filename, np.array(img, label, tr_label))
        
        elif abs(label) <= 130 and abs(label) > 140:
            path = '../../data/commaai/train_bags/13/'
            filename = str(path + str(i))
            np.save(filename, np.array(img, label, tr_label))
        
        elif abs(label) <= 140 and abs(label) > 130:
            path = '../../data/commaai/train_bags/14/'
            filename = str(path + str(i))
            np.save(filename, np.array(img, label, tr_label))
        
        elif abs(label) <= 150 and abs(label) > 140:
            path = '../../data/commaai/train_bags/15/'
            filename = str(path + str(i))
            np.save(filename, np.array(img, label, tr_label))
        
        elif abs(label) <= 160 and abs(label) > 150:
            path = '../../data/commaai/train_bags/16/'
            filename = str(path + str(i))
            np.save(filename, np.array(img, label, tr_label))
        
        elif abs(label) <= 170 and abs(label) > 160:
            path = '../../data/commaai/train_bags/17/'
            filename = str(path + str(i))
            np.save(filename, np.array(img, label, tr_label))
        
        elif abs(label) <= 180 and abs(label) > 170:
            path = '../../data/commaai/train_bags/18/'
            filename = str(path + str(i))
            np.save(filename, np.array(img, label, tr_label))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-38-898ef7fe81b5> in <module>
#       5     time_file = train_time_files[i]
#       6
# ----> 7     images, yaw, trans_label = read_vid_angles(video_file, angle_file, time_file, density)
#       8
#       9     for i, (img, label, tr_label) in enumerate(zip(images, yaw, trans_label)):
#
# <ipython-input-37-d74391c11082> in read_vid_angles(vid_path, value_path, t_path, density)
#      30     rez_frames = []
#      31     for i in range(0, frames.shape[0]):
# ---> 32         frames_i = cv2.resize(frames[i, :, :, :], dsize = (new_height,new_width), interpolation = cv2.BILINEAR)
#      33         rez_frames.append(frames_i)
#      34     frames_i = np.array(frames_i)
#
# AttributeError: module 'cv2.cv2' has no attribute 'BILINEAR'

# %%
train_yaw_files[0]
# Out:
# '../../data/commaai/destinationChunk_1_b0c9d2329ad1606b_2018-07-27--06-03-57_8.value'

# %%
train_time_files
# Out:
# ['../../data/commaai/destinationChunk_1_b0c9d2329ad1606b_2018-07-27--06-03-57_8.t',
#  '../../data/commaai/destinationChunk_9_99c94dc769b5d96e_2018-11-04--08-49-46_31.t',
#  '../../data/commaai/destinationChunk_9_99c94dc769b5d96e_2018-11-04--08-49-46_34.t',
#  '../../data/commaai/destinationChunk_9_99c94dc769b5d96e_2018-11-04--08-49-46_32.t',
#  '../../data/commaai/destinationChunk_9_99c94dc769b5d96e_2018-11-04--08-49-46_26.t',
#  '../../data/commaai/destinationChunk_9_99c94dc769b5d96e_2018-11-04--08-49-46_27.t',
#  '../../data/commaai/destinationChunk_9_99c94dc769b5d96e_2018-11-04--08-49-46_29.t',
#  '../../data/commaai/destinationChunk_9_99c94dc769b5d96e_2018-11-04--08-49-46_33.t',
#  '../../data/commaai/destinationChunk_9_99c94dc769b5d96e_2018-11-04--08-49-46_35.t',
#  '../../data/commaai/destinationChunk_9_99c94dc769b5d96e_2018-11-04--08-49-46_28.t',
#  '../../data/commaai/destinationChunk_9_99c94dc769b5d96e_2018-11-04--08-49-46_25.t',
#  '../../data/commaai/destinationChunk_9_99c94dc769b5d96e_2018-11-04--08-49-46_24.t',
#  '../../data/commaai/destinationChunk_9_99c94dc769b5d96e_2018-11-04--08-49-46_30.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-16--23-46-35_10.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-25--21-14-19_10.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-16--23-46-35_15.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-25--21-14-19_5.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-25--21-14-19_3.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-25--21-14-19_1.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-16--23-46-35_11.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-25--21-14-19_9.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-25--21-14-19_6.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-16--23-46-35_12.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-16--23-46-35_14.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-16--23-46-35_16.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-25--21-14-19_4.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-25--21-14-19_2.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-16--23-46-35_13.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-25--21-14-19_12.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-25--21-14-19_8.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-16--23-46-35_6.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-16--23-46-35_4.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-16--23-46-35_7.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-25--21-14-19_11.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-16--23-46-35_9.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-16--23-46-35_8.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-16--23-46-35_5.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-16--15-11-03_3.t',
#  '../../data/commaai/destinationChunk_9_99c94dc769b5d96e_2018-10-16--10-13-38_10.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-13--10-09-22_47.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-13--10-09-22_42.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-16--15-11-03_11.t',
#  '../../data/commaai/destinationChunk_9_99c94dc769b5d96e_2018-10-16--10-13-38_6.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-16--15-11-03_16.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-25--21-14-19_7.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-13--10-09-22_50.t',
#  '../../data/commaai/destinationChunk_9_99c94dc769b5d96e_2018-10-16--10-13-38_5.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-16--15-11-03_0.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-13--10-09-22_48.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-16--15-11-03_6.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-13--10-09-22_44.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-16--15-11-03_15.t',
#  '../../data/commaai/destinationChunk_9_99c94dc769b5d96e_2018-10-16--10-13-38_4.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-16--15-11-03_8.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-13--10-09-22_38.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-16--15-11-03_19.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-13--10-09-22_41.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-16--15-11-03_12.t',
#  '../../data/commaai/destinationChunk_9_99c94dc769b5d96e_2018-10-16--10-13-38_2.t',
#  '../../data/commaai/destinationChunk_9_99c94dc769b5d96e_2018-10-16--10-13-38_3.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-16--15-11-03_17.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-16--15-11-03_14.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-25--22-19-02_7.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-13--10-09-22_43.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-13--10-09-22_45.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-16--15-11-03_1.t',
#  '../../data/commaai/destinationChunk_9_99c94dc769b5d96e_2018-10-16--10-13-38_8.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-16--15-11-03_10.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-13--10-09-22_40.t',
#  '../../data/commaai/destinationChunk_9_99c94dc769b5d96e_2018-10-16--10-13-38_7.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-25--22-19-02_6.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-16--15-11-03_13.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-16--15-11-03_18.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-13--10-09-22_49.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-25--22-19-02_13.t',
#  '../../data/commaai/destinationChunk_9_99c94dc769b5d96e_2018-10-16--10-13-38_9.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-16--15-11-03_2.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-13--10-09-22_46.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-16--15-11-03_5.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-25--22-19-02_8.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-16--15-11-03_4.t',
#  '../../data/commaai/destinationChunk_9_99c94dc769b5d96e_2018-10-16--10-13-38_11.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-25--22-19-02_9.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-16--15-11-03_9.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-25--22-19-02_4.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-13--10-09-22_39.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-25--22-19-02_5.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-25--22-19-02_11.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-25--22-19-02_10.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-25--22-19-02_15.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-25--22-19-02_12.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-16--15-11-03_7.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-25--22-19-02_14.t',
#  '../../data/commaai/destinationChunk_1_b0c9d2329ad1606b_2018-07-30--13-44-30_8.t',
#  '../../data/commaai/destinationChunk_1_b0c9d2329ad1606b_2018-07-27--06-03-57_4.t',
#  '../../data/commaai/destinationChunk_1_b0c9d2329ad1606b_2018-07-30--13-44-30_11.t',
#  '../../data/commaai/destinationChunk_1_b0c9d2329ad1606b_2018-07-30--13-44-30_9.t',
#  '../../data/commaai/destinationChunk_1_b0c9d2329ad1606b_2018-07-27--06-03-57_5.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-15--01-05-25_1.t',
#  '../../data/commaai/destinationChunk_1_b0c9d2329ad1606b_2018-07-30--13-44-30_10.t',
#  '../../data/commaai/destinationChunk_1_b0c9d2329ad1606b_2018-07-27--06-03-57_6.t',
#  '../../data/commaai/destinationChunk_1_b0c9d2329ad1606b_2018-07-30--13-44-30_12.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-15--01-05-25_5.t',
#  '../../data/commaai/destinationChunk_1_b0c9d2329ad1606b_2018-07-27--06-03-57_10.t',
#  '../../data/commaai/destinationChunk_1_b0c9d2329ad1606b_2018-07-30--13-44-30_14.t',
#  '../../data/commaai/destinationChunk_1_b0c9d2329ad1606b_2018-07-30--13-44-30_13.t',
#  '../../data/commaai/destinationChunk_1_b0c9d2329ad1606b_2018-07-30--13-44-30_15.t',
#  '../../data/commaai/destinationChunk_1_b0c9d2329ad1606b_2018-07-27--06-03-57_3.t',
#  '../../data/commaai/destinationChunk_1_b0c9d2329ad1606b_2018-07-30--13-44-30_7.t',
#  '../../data/commaai/destinationChunk_1_b0c9d2329ad1606b_2018-07-27--06-03-57_11.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-07-02--19-08-27_7.t',
#  '../../data/commaai/destinationChunk_1_b0c9d2329ad1606b_2018-07-30--13-44-30_6.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-07-02--19-08-27_13.t',
#  '../../data/commaai/destinationChunk_1_b0c9d2329ad1606b_2018-07-27--06-03-57_7.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-07-02--19-08-27_6.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-07-02--19-08-27_12.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-07-02--19-08-27_16.t',
#  '../../data/commaai/destinationChunk_1_b0c9d2329ad1606b_2018-08-03--10-35-16_11.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-07-02--19-08-27_8.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-07-02--19-08-27_5.t',
#  '../../data/commaai/destinationChunk_1_b0c9d2329ad1606b_2018-08-03--10-35-16_9.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-07-02--19-08-27_11.t',
#  '../../data/commaai/destinationChunk_1_b0c9d2329ad1606b_2018-08-03--10-35-16_16.t',
#  '../../data/commaai/destinationChunk_1_b0c9d2329ad1606b_2018-08-03--10-35-16_13.t',
#  '../../data/commaai/destinationChunk_1_b0c9d2329ad1606b_2018-08-03--10-35-16_12.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-07-02--19-08-27_15.t',
#  '../../data/commaai/destinationChunk_1_b0c9d2329ad1606b_2018-08-03--10-35-16_15.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-07-02--19-08-27_9.t',
#  '../../data/commaai/destinationChunk_1_b0c9d2329ad1606b_2018-08-03--10-35-16_14.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-07-02--19-08-27_14.t',
#  '../../data/commaai/destinationChunk_1_b0c9d2329ad1606b_2018-08-03--10-35-16_8.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-07-02--19-08-27_17.t',
#  '../../data/commaai/destinationChunk_1_b0c9d2329ad1606b_2018-08-03--10-35-16_5.t',
#  '../../data/commaai/destinationChunk_1_b0c9d2329ad1606b_2018-07-27--06-03-57_9.t',
#  '../../data/commaai/destinationChunk_1_b0c9d2329ad1606b_2018-08-03--10-35-16_4.t',
#  '../../data/commaai/destinationChunk_1_b0c9d2329ad1606b_2018-08-03--10-35-16_10.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-24--12-20-02_21.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-24--12-20-02_20.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-24--12-20-02_23.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-24--12-20-02_22.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-27--15-03-44_73.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-27--15-03-44_65.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-27--15-03-44_70.t',
#  '../../data/commaai/destinationChunk_1_b0c9d2329ad1606b_2018-08-03--10-35-16_7.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-27--15-03-44_12.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-27--15-03-44_67.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-22--20-13-04_4.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-22--20-13-04_10.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-27--15-03-44_69.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-12--23-26-14_9.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-12--23-26-14_8.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-12--23-26-14_13.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-22--20-13-04_9.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-12--23-26-14_12.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-07-02--19-08-27_10.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-22--20-13-04_12.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-27--15-03-44_63.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-22--20-13-04_5.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-22--20-13-04_3.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-22--20-13-04_7.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-12--23-26-14_5.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-27--15-03-44_74.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-12--23-26-14_6.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-22--20-13-04_6.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-12--23-26-14_15.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-27--15-03-44_15.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-12--23-26-14_14.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-27--15-03-44_13.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-22--20-13-04_1.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-22--20-13-04_2.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-27--15-03-44_68.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-22--20-13-04_13.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-22--20-13-04_8.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-27--15-03-44_11.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-12--23-26-14_16.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-22--20-13-04_11.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-15--01-05-25_7.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-27--15-03-44_72.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-12--23-26-14_7.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-12--23-26-14_10.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-27--15-03-44_71.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-12--23-26-14_4.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-27--15-03-44_10.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-12--23-26-14_11.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-27--15-03-44_14.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-12--18-52-46_0.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-27--15-03-44_18.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-27--15-03-44_64.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-27--15-03-44_16.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-27--15-03-44_17.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-08--08-43-22_43.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-15--01-05-25_2.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-15--01-05-25_3.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-08--08-43-22_51.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-27--15-03-44_66.t',
#  '../../data/commaai/destinationChunk_1_b0c9d2329ad1606b_2018-07-29--11-17-20_4.t',
#  '../../data/commaai/destinationChunk_1_b0c9d2329ad1606b_2018-07-29--11-17-20_7.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-08--08-43-22_41.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-08--08-43-22_42.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-08--08-43-22_40.t',
#  '../../data/commaai/destinationChunk_1_b0c9d2329ad1606b_2018-07-29--11-17-20_5.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-08--08-43-22_47.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-15--01-05-25_0.t',
#  '../../data/commaai/destinationChunk_1_b0c9d2329ad1606b_2018-07-29--11-17-20_3.t',
#  '../../data/commaai/destinationChunk_1_b0c9d2329ad1606b_2018-07-29--11-17-20_6.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-08--08-43-22_50.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-08--08-43-22_48.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-15--01-05-25_4.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-08--08-43-22_45.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-08--08-43-22_49.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-08--08-43-22_46.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-15--19-55-32_6.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-08--08-43-22_39.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-15--19-55-32_13.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-15--01-05-25_6.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-15--19-55-32_10.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-15--19-55-32_9.t',
#  '../../data/commaai/destinationChunk_1_b0c9d2329ad1606b_2018-08-01--21-13-49_7.t',
#  '../../data/commaai/destinationChunk_1_b0c9d2329ad1606b_2018-08-01--21-13-49_5.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-15--19-55-32_30.t',
#  '../../data/commaai/destinationChunk_1_b0c9d2329ad1606b_2018-08-01--21-13-49_6.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-15--19-55-32_14.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-15--19-55-32_31.t',
#  '../../data/commaai/destinationChunk_1_b0c9d2329ad1606b_2018-08-01--21-13-49_8.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-15--19-55-32_7.t',
#  '../../data/commaai/destinationChunk_1_b0c9d2329ad1606b_2018-08-01--21-13-49_10.t',
#  '../../data/commaai/destinationChunk_1_b0c9d2329ad1606b_2018-08-01--21-13-49_11.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-08--08-43-22_44.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-15--19-55-32_32.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-14--13-31-42_28.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-14--13-31-42_32.t',
#  '../../data/commaai/destinationChunk_1_b0c9d2329ad1606b_2018-08-01--21-13-49_13.t',
#  '../../data/commaai/destinationChunk_1_b0c9d2329ad1606b_2018-08-01--21-13-49_14.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-14--13-31-42_26.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-14--13-31-42_35.t',
#  '../../data/commaai/destinationChunk_1_b0c9d2329ad1606b_2018-08-01--21-13-49_9.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-14--13-31-42_36.t',
#  '../../data/commaai/destinationChunk_1_b0c9d2329ad1606b_2018-08-01--21-13-49_12.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-14--13-31-42_29.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-14--13-31-42_34.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-14--13-31-42_27.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-14--13-31-42_31.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-14--13-31-42_30.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-14--13-31-42_33.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-14--13-31-42_38.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-14--13-31-42_37.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-14--13-31-42_39.t',
#  '../../data/commaai/destinationChunk_1_b0c9d2329ad1606b_2018-07-27--06-50-48_11.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-15--19-55-32_15.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-15--19-55-32_11.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-15--19-55-32_29.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-16--10-00-42_44.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-15--19-55-32_12.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-16--10-00-42_32.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-15--19-55-32_28.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-16--10-00-42_33.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-09--19-18-40_50.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-15--19-55-32_8.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-16--10-00-42_35.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-16--10-00-42_40.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-16--10-00-42_39.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-16--10-00-42_36.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-16--10-00-42_42.t',
#  '../../data/commaai/destinationChunk_1_b0c9d2329ad1606b_2018-07-27--06-50-48_13.t',
#  '../../data/commaai/destinationChunk_1_b0c9d2329ad1606b_2018-07-27--06-50-48_7.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-16--10-00-42_37.t',
#  '../../data/commaai/destinationChunk_1_b0c9d2329ad1606b_2018-07-27--06-50-48_10.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-09--19-18-40_52.t',
#  '../../data/commaai/destinationChunk_1_b0c9d2329ad1606b_2018-07-27--06-50-48_8.t',
#  '../../data/commaai/destinationChunk_1_b0c9d2329ad1606b_2018-07-27--06-50-48_9.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-16--10-00-42_43.t',
#  '../../data/commaai/destinationChunk_1_b0c9d2329ad1606b_2018-07-27--06-50-48_12.t',
#  '../../data/commaai/destinationChunk_1_b0c9d2329ad1606b_2018-07-27--06-50-48_14.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-21--18-27-56_4.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-21--18-27-56_5.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-16--10-00-42_34.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-16--10-00-42_41.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-21--18-27-56_6.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-16--10-00-42_38.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-09--19-18-40_47.t',
#  '../../data/commaai/destinationChunk_1_b0c9d2329ad1606b_2018-08-16--21-52-30_8.t',
#  '../../data/commaai/destinationChunk_1_b0c9d2329ad1606b_2018-08-16--21-52-30_5.t',
#  '../../data/commaai/destinationChunk_1_b0c9d2329ad1606b_2018-08-16--21-52-30_6.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-24--14-01-30_19.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-24--14-01-30_15.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-24--14-01-30_20.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-09--19-18-40_31.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-16--15-02-13_8.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-24--14-01-30_14.t',
#  '../../data/commaai/destinationChunk_1_b0c9d2329ad1606b_2018-07-30--13-03-07_18.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-16--15-02-13_7.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-24--14-01-30_9.t',
#  '../../data/commaai/destinationChunk_1_b0c9d2329ad1606b_2018-07-30--13-03-07_15.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-09--19-18-40_35.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-24--14-01-30_16.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-24--14-01-30_13.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-24--14-01-30_11.t',
#  '../../data/commaai/destinationChunk_1_b0c9d2329ad1606b_2018-07-30--13-03-07_17.t',
#  '../../data/commaai/destinationChunk_1_b0c9d2329ad1606b_2018-07-30--13-03-07_22.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-09--19-18-40_42.t',
#  '../../data/commaai/destinationChunk_1_b0c9d2329ad1606b_2018-07-30--13-03-07_16.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-24--14-01-30_12.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-24--14-01-30_17.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-24--14-01-30_10.t',
#  '../../data/commaai/destinationChunk_1_b0c9d2329ad1606b_2018-07-30--13-03-07_14.t',
#  '../../data/commaai/destinationChunk_1_b0c9d2329ad1606b_2018-07-30--13-03-07_21.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-09--19-18-40_46.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-24--14-01-30_8.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-09--19-18-40_34.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-24--14-01-30_18.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-09--20-49-26_9.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-09--19-18-40_53.t',
#  '../../data/commaai/destinationChunk_1_b0c9d2329ad1606b_2018-07-30--13-03-07_20.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-09--19-18-40_38.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-09--19-18-40_49.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-09--19-18-40_32.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-09--19-18-40_30.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-09--20-49-26_4.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-09--19-18-40_33.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-09--20-49-26_14.t',
#  '../../data/commaai/destinationChunk_1_b0c9d2329ad1606b_2018-08-02--16-41-38_8.t',
#  '../../data/commaai/destinationChunk_1_b0c9d2329ad1606b_2018-08-02--16-41-38_13.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-09--20-49-26_12.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-09--20-49-26_7.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-24--15-20-06_14.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-09--20-49-26_2.t',
#  '../../data/commaai/destinationChunk_1_b0c9d2329ad1606b_2018-08-02--16-41-38_5.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-09--19-18-40_55.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-09--19-18-40_45.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-24--15-20-06_9.t',
#  '../../data/commaai/destinationChunk_1_b0c9d2329ad1606b_2018-08-02--16-41-38_11.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-09--19-18-40_41.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-09--19-18-40_48.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-09--20-49-26_11.t',
#  '../../data/commaai/destinationChunk_1_b0c9d2329ad1606b_2018-08-02--16-41-38_6.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-24--15-20-06_16.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-24--15-20-06_10.t',
#  '../../data/commaai/destinationChunk_1_b0c9d2329ad1606b_2018-08-02--16-41-38_17.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-09--19-18-40_39.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-09--19-18-40_40.t',
#  '../../data/commaai/destinationChunk_1_b0c9d2329ad1606b_2018-08-02--16-41-38_10.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-24--15-20-06_11.t',
#  '../../data/commaai/destinationChunk_1_b0c9d2329ad1606b_2018-08-02--16-41-38_12.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-09--19-18-40_36.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-09--20-49-26_3.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-24--15-20-06_13.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-09--19-18-40_37.t',
#  '../../data/commaai/destinationChunk_1_b0c9d2329ad1606b_2018-08-02--16-41-38_14.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-09--20-49-26_10.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-09--20-49-26_13.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-24--15-20-06_6.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-24--15-20-06_5.t',
#  '../../data/commaai/destinationChunk_1_b0c9d2329ad1606b_2018-08-02--16-41-38_9.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-09--19-18-40_43.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-24--15-20-06_4.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-24--15-20-06_12.t',
#  '../../data/commaai/destinationChunk_1_b0c9d2329ad1606b_2018-08-02--16-41-38_7.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-09--20-49-26_5.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-24--15-20-06_15.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-24--15-20-06_8.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-09--19-18-40_56.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-09--19-18-40_51.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-24--15-20-06_7.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-07--10-06-00_32.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-07--10-06-00_29.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-09--20-49-26_6.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-07--10-06-00_31.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-07--10-06-00_24.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-07--10-06-00_27.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-25--10-11-05_31.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-07--10-06-00_26.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-07--10-06-00_25.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-25--10-11-05_35.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-07--10-06-00_22.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-09--20-49-26_8.t',
#  '../../data/commaai/destinationChunk_1_b0c9d2329ad1606b_2018-08-14--20-41-07_6.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-07--10-06-00_21.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-25--10-11-05_30.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-07--10-06-00_28.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-25--10-11-05_33.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-07--10-06-00_30.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-19--09-56-45_22.t',
#  '../../data/commaai/destinationChunk_1_b0c9d2329ad1606b_2018-08-14--20-41-07_11.t',
#  '../../data/commaai/destinationChunk_1_b0c9d2329ad1606b_2018-08-14--20-41-07_16.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-07--10-06-00_23.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-19--09-56-45_25.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-25--10-11-05_26.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-25--10-11-05_32.t',
#  '../../data/commaai/destinationChunk_1_b0c9d2329ad1606b_2018-08-14--20-41-07_15.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-07--10-06-00_20.t',
#  '../../data/commaai/destinationChunk_1_b0c9d2329ad1606b_2018-08-14--20-41-07_12.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-19--09-56-45_30.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-25--10-11-05_27.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-19--09-56-45_32.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-25--10-11-05_34.t',
#  '../../data/commaai/destinationChunk_1_b0c9d2329ad1606b_2018-08-14--20-41-07_4.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-25--10-11-05_28.t',
#  '../../data/commaai/destinationChunk_1_b0c9d2329ad1606b_2018-08-14--20-41-07_7.t',
#  '../../data/commaai/destinationChunk_1_b0c9d2329ad1606b_2018-08-14--20-41-07_9.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-19--09-56-45_23.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-25--10-11-05_29.t',
#  '../../data/commaai/destinationChunk_1_b0c9d2329ad1606b_2018-08-14--20-41-07_10.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-25--10-11-05_37.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-25--10-11-05_36.t',
#  '../../data/commaai/destinationChunk_1_b0c9d2329ad1606b_2018-08-14--20-41-07_5.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-25--20-56-44_4.t',
#  '../../data/commaai/destinationChunk_1_b0c9d2329ad1606b_2018-08-14--20-41-07_14.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-19--09-56-45_27.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-25--20-56-44_7.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-19--09-56-45_33.t',
#  '../../data/commaai/destinationChunk_1_b0c9d2329ad1606b_2018-08-14--20-41-07_13.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-25--20-56-44_6.t',
#  '../../data/commaai/destinationChunk_1_b0c9d2329ad1606b_2018-08-14--20-41-07_8.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-25--20-56-44_3.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-15--01-02-09_2.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-25--20-56-44_12.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-25--20-56-44_13.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-19--09-56-45_31.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-25--20-56-44_10.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-15--01-02-09_0.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-15--01-02-09_3.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-25--20-56-44_9.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-25--20-56-44_5.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-25--20-56-44_8.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-19--09-56-45_26.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-15--01-02-09_1.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-25--20-56-44_2.t',
#  '../../data/commaai/destinationChunk_1_b0c9d2329ad1606b_2018-08-14--10-32-01_36.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-25--20-56-44_11.t',
#  '../../data/commaai/destinationChunk_1_b0c9d2329ad1606b_2018-08-14--10-32-01_28.t',
#  '../../data/commaai/destinationChunk_1_b0c9d2329ad1606b_2018-08-14--10-32-01_37.t',
#  '../../data/commaai/destinationChunk_1_b0c9d2329ad1606b_2018-08-14--10-32-01_30.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-19--09-56-45_29.t',
#  '../../data/commaai/destinationChunk_1_b0c9d2329ad1606b_2018-08-14--10-32-01_34.t',
#  '../../data/commaai/destinationChunk_1_b0c9d2329ad1606b_2018-08-14--10-32-01_32.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-19--09-56-45_28.t',
#  '../../data/commaai/destinationChunk_1_b0c9d2329ad1606b_2018-08-14--10-32-01_35.t',
#  '../../data/commaai/destinationChunk_1_b0c9d2329ad1606b_2018-08-14--10-32-01_29.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-19--09-56-45_24.t',
#  '../../data/commaai/destinationChunk_1_b0c9d2329ad1606b_2018-08-14--10-32-01_26.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-07--20-57-42_7.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-07--20-57-42_8.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-07--20-57-42_12.t',
#  '../../data/commaai/destinationChunk_1_b0c9d2329ad1606b_2018-08-14--10-32-01_27.t',
#  '../../data/commaai/destinationChunk_1_b0c9d2329ad1606b_2018-08-14--10-32-01_33.t',
#  '../../data/commaai/destinationChunk_1_b0c9d2329ad1606b_2018-08-14--10-32-01_31.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-07--20-57-42_6.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-07--20-57-42_5.t',
#  '../../data/commaai/destinationChunk_1_b0c9d2329ad1606b_2018-08-14--10-32-01_38.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-07--20-57-42_10.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-07--20-57-42_4.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-07--20-57-42_11.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-18--21-20-21_31.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-07--20-57-42_9.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-07--20-57-42_3.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-18--21-20-21_10.t',
#  '../../data/commaai/destinationChunk_1_b0c9d2329ad1606b_2018-08-17--12-07-08_38.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-07-02--09-20-11_30.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-18--21-20-21_29.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-18--21-20-21_11.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-18--21-20-21_17.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-18--21-20-21_38.t',
#  '../../data/commaai/destinationChunk_1_b0c9d2329ad1606b_2018-08-17--12-07-08_39.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-18--21-20-21_28.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-13--21-14-19_10.t',
#  '../../data/commaai/destinationChunk_1_b0c9d2329ad1606b_2018-08-17--12-07-08_36.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-07-02--09-20-11_38.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-13--21-14-19_14.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-18--21-20-21_36.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-13--21-14-19_12.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-18--21-20-21_9.t',
#  '../../data/commaai/destinationChunk_1_b0c9d2329ad1606b_2018-08-17--12-07-08_33.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-13--21-14-19_9.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-18--21-20-21_8.t',
#  '../../data/commaai/destinationChunk_1_b0c9d2329ad1606b_2018-08-17--12-07-08_32.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-13--21-14-19_3.t',
#  '../../data/commaai/destinationChunk_1_b0c9d2329ad1606b_2018-08-17--12-07-08_29.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-18--21-20-21_16.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-18--21-20-21_7.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-07-02--09-20-11_32.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-07-02--09-20-11_37.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-13--21-14-19_5.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-13--21-14-19_7.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-13--21-14-19_8.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-07-02--09-20-11_29.t',
#  '../../data/commaai/destinationChunk_1_b0c9d2329ad1606b_2018-08-17--12-07-08_27.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-13--21-14-19_6.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-18--21-20-21_5.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-18--21-20-21_32.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-18--21-20-21_6.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-13--21-14-19_13.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-07-02--09-20-11_33.t',
#  '../../data/commaai/destinationChunk_1_b0c9d2329ad1606b_2018-08-17--12-07-08_28.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-18--21-20-21_33.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-13--21-14-19_4.t',
#  '../../data/commaai/destinationChunk_1_b0c9d2329ad1606b_2018-08-17--12-07-08_40.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-18--21-20-21_12.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-18--21-20-21_14.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-13--21-14-19_11.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-18--21-20-21_34.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-18--21-20-21_27.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-18--21-20-21_15.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-18--21-20-21_37.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-18--21-20-21_30.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-18--21-20-21_35.t',
#  '../../data/commaai/destinationChunk_1_b0c9d2329ad1606b_2018-08-17--12-07-08_31.t',
#  '../../data/commaai/destinationChunk_1_b0c9d2329ad1606b_2018-07-31--20-50-28_9.t',
#  '../../data/commaai/destinationChunk_1_b0c9d2329ad1606b_2018-07-31--20-50-28_13.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-07-02--09-20-11_34.t',
#  '../../data/commaai/destinationChunk_1_b0c9d2329ad1606b_2018-07-31--20-50-28_12.t',
#  '../../data/commaai/destinationChunk_1_b0c9d2329ad1606b_2018-08-17--12-07-08_30.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-07-02--09-20-11_36.t',
#  '../../data/commaai/destinationChunk_1_b0c9d2329ad1606b_2018-07-31--20-50-28_6.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-06-18--21-20-21_13.t',
#  '../../data/commaai/destinationChunk_1_b0c9d2329ad1606b_2018-07-31--20-50-28_7.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-07-02--09-20-11_31.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-07-02--09-20-11_35.t',
#  '../../data/commaai/destinationChunk_1_b0c9d2329ad1606b_2018-07-31--20-50-28_5.t',
#  '../../data/commaai/destinationChunk_1_b0c9d2329ad1606b_2018-08-17--12-07-08_41.t',
#  '../../data/commaai/destinationChunk_1_b0c9d2329ad1606b_2018-08-17--12-07-08_34.t',
#  '../../data/commaai/destinationChunk_1_b0c9d2329ad1606b_2018-07-31--20-50-28_8.t',
#  '../../data/commaai/destinationChunk_4_99c94dc769b5d96e_2018-07-02--09-20-11_39.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-15--10-31-50_37.t',
#  '../../data/commaai/destinationChunk_1_b0c9d2329ad1606b_2018-08-17--12-07-08_35.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-15--10-31-50_46.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-15--10-31-50_41.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-15--10-31-50_40.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-15--10-31-50_39.t',
#  '../../data/commaai/destinationChunk_1_b0c9d2329ad1606b_2018-08-17--12-07-08_37.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-15--10-31-50_45.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-15--21-00-40_5.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-15--21-00-40_14.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-15--10-31-50_38.t',
#  '../../data/commaai/destinationChunk_1_b0c9d2329ad1606b_2018-08-06--10-04-53_25.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-15--10-31-50_44.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-15--21-00-40_10.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-15--21-00-40_13.t',
#  '../../data/commaai/destinationChunk_1_b0c9d2329ad1606b_2018-08-06--10-04-53_30.t',
#  '../../data/commaai/destinationChunk_1_b0c9d2329ad1606b_2018-08-06--10-04-53_36.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-15--10-31-50_36.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-15--21-00-40_11.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-15--21-00-40_6.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-15--10-31-50_34.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-15--21-00-40_8.t',
#  '../../data/commaai/destinationChunk_1_b0c9d2329ad1606b_2018-08-06--10-04-53_31.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-15--10-31-50_43.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-15--21-00-40_9.t',
#  '../../data/commaai/destinationChunk_1_b0c9d2329ad1606b_2018-08-06--10-04-53_35.t',
#  '../../data/commaai/destinationChunk_1_b0c9d2329ad1606b_2018-08-06--10-04-53_32.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-15--21-00-40_3.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-15--10-31-50_35.t',
#  '../../data/commaai/destinationChunk_1_b0c9d2329ad1606b_2018-08-17--14-55-39_4.t',
#  '../../data/commaai/destinationChunk_1_b0c9d2329ad1606b_2018-08-06--10-04-53_26.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-15--21-00-40_12.t',
#  '../../data/commaai/destinationChunk_1_b0c9d2329ad1606b_2018-08-06--10-04-53_33.t',
#  '../../data/commaai/destinationChunk_1_b0c9d2329ad1606b_2018-08-17--14-55-39_5.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-15--10-31-50_42.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-15--21-00-40_7.t',
#  '../../data/commaai/destinationChunk_1_b0c9d2329ad1606b_2018-08-17--14-55-39_8.t',
#  '../../data/commaai/destinationChunk_10_99c94dc769b5d96e_2018-11-15--21-00-40_4.t',
#  '../../data/commaai/destinationChunk_1_b0c9d2329ad1606b_2018-08-17--14-55-39_2.t',
#  '../../data/commaai/destinationChunk_1_b0c9d2329ad1606b_2018-08-06--10-04-53_29.t',
#  '../../data/commaai/destinationChunk_1_b0c9d2329ad1606b_2018-08-17--14-55-39_9.t',
#  '../../data/commaai/destinationChunk_1_b0c9d2329ad1606b_2018-08-17--14-55-39_7.t',
# ...
#  '../../data/commaai/destinationChunk_5_99c94dc769b5d96e_2018-07-03--14-38-26_28.t',
#  '../../data/commaai/destinationChunk_5_99c94dc769b5d96e_2018-07-05--20-49-41_31.t',
#  '../../data/commaai/destinationChunk_5_99c94dc769b5d96e_2018-07-06--09-43-54_40.t',
#  '../../data/commaai/destinationChunk_5_99c94dc769b5d96e_2018-07-03--14-38-26_16.t',
#  '../../data/commaai/destinationChunk_5_99c94dc769b5d96e_2018-07-05--20-49-41_21.t',
#  '../../data/commaai/destinationChunk_5_99c94dc769b5d96e_2018-07-06--09-43-54_38.t',
#  '../../data/commaai/destinationChunk_5_99c94dc769b5d96e_2018-07-03--14-38-26_25.t',
#  '../../data/commaai/destinationChunk_5_99c94dc769b5d96e_2018-07-05--20-49-41_28.t',
#  '../../data/commaai/destinationChunk_3_99c94dc769b5d96e_2018-05-18--16-00-42_56.t',
#  '../../data/commaai/destinationChunk_5_99c94dc769b5d96e_2018-07-06--09-43-54_30.t',
#  '../../data/commaai/destinationChunk_5_99c94dc769b5d96e_2018-07-05--20-49-41_11.t',
#  '../../data/commaai/destinationChunk_3_99c94dc769b5d96e_2018-05-18--16-00-42_62.t',
#  '../../data/commaai/destinationChunk_5_99c94dc769b5d96e_2018-07-05--20-49-41_10.t',
#  '../../data/commaai/destinationChunk_5_99c94dc769b5d96e_2018-07-06--09-43-54_36.t',
#  '../../data/commaai/destinationChunk_3_99c94dc769b5d96e_2018-05-18--16-00-42_63.t',
#  '../../data/commaai/destinationChunk_3_99c94dc769b5d96e_2018-05-18--16-00-42_69.t',
#  '../../data/commaai/destinationChunk_5_99c94dc769b5d96e_2018-07-06--09-43-54_33.t',
#  '../../data/commaai/destinationChunk_5_99c94dc769b5d96e_2018-07-05--20-49-41_30.t',
#  '../../data/commaai/destinationChunk_3_99c94dc769b5d96e_2018-05-18--16-00-42_52.t',
#  '../../data/commaai/destinationChunk_3_99c94dc769b5d96e_2018-05-18--16-00-42_57.t',
#  '../../data/commaai/destinationChunk_3_99c94dc769b5d96e_2018-05-18--16-00-42_58.t',
#  '../../data/commaai/destinationChunk_3_99c94dc769b5d96e_2018-05-18--16-00-42_55.t',
#  '../../data/commaai/destinationChunk_5_99c94dc769b5d96e_2018-07-06--09-43-54_37.t',
#  '../../data/commaai/destinationChunk_5_99c94dc769b5d96e_2018-07-06--01-15-15_34.t',
#  '../../data/commaai/destinationChunk_3_99c94dc769b5d96e_2018-05-18--16-00-42_72.t',
#  '../../data/commaai/destinationChunk_3_99c94dc769b5d96e_2018-05-18--16-00-42_61.t',
#  '../../data/commaai/destinationChunk_5_99c94dc769b5d96e_2018-07-06--09-43-54_35.t',
#  '../../data/commaai/destinationChunk_5_99c94dc769b5d96e_2018-07-06--09-43-54_34.t',
#  '../../data/commaai/destinationChunk_3_99c94dc769b5d96e_2018-05-18--16-00-42_64.t',
#  '../../data/commaai/destinationChunk_3_99c94dc769b5d96e_2018-05-18--16-00-42_59.t',
#  '../../data/commaai/destinationChunk_5_99c94dc769b5d96e_2018-07-06--01-15-15_30.t',
#  '../../data/commaai/destinationChunk_5_99c94dc769b5d96e_2018-07-06--01-15-15_27.t',
#  '../../data/commaai/destinationChunk_5_99c94dc769b5d96e_2018-07-06--01-15-15_28.t',
#  '../../data/commaai/destinationChunk_5_99c94dc769b5d96e_2018-07-05--10-05-06_36.t',
#  '../../data/commaai/destinationChunk_5_99c94dc769b5d96e_2018-07-06--01-15-15_29.t',
#  '../../data/commaai/destinationChunk_5_99c94dc769b5d96e_2018-07-06--01-15-15_32.t',
#  '../../data/commaai/destinationChunk_5_99c94dc769b5d96e_2018-07-05--10-05-06_29.t',
#  '../../data/commaai/destinationChunk_5_99c94dc769b5d96e_2018-07-06--01-15-15_26.t',
#  '../../data/commaai/destinationChunk_5_99c94dc769b5d96e_2018-07-05--10-05-06_25.t',
#  '../../data/commaai/destinationChunk_5_99c94dc769b5d96e_2018-07-06--01-15-15_25.t',
#  '../../data/commaai/destinationChunk_5_99c94dc769b5d96e_2018-07-06--01-15-15_23.t',
#  '../../data/commaai/destinationChunk_5_99c94dc769b5d96e_2018-07-04--00-20-19_19.t',
#  '../../data/commaai/destinationChunk_5_99c94dc769b5d96e_2018-07-06--01-15-15_24.t',
#  '../../data/commaai/destinationChunk_5_99c94dc769b5d96e_2018-07-05--10-05-06_34.t',
#  '../../data/commaai/destinationChunk_5_99c94dc769b5d96e_2018-07-05--10-05-06_31.t',
#  '../../data/commaai/destinationChunk_5_99c94dc769b5d96e_2018-07-05--10-05-06_26.t',
#  '../../data/commaai/destinationChunk_5_99c94dc769b5d96e_2018-07-06--01-15-15_33.t',
#  '../../data/commaai/destinationChunk_5_99c94dc769b5d96e_2018-07-05--10-05-06_32.t',
#  '../../data/commaai/destinationChunk_5_99c94dc769b5d96e_2018-07-04--00-20-19_11.t',
#  '../../data/commaai/destinationChunk_5_99c94dc769b5d96e_2018-07-05--10-05-06_30.t',
#  '../../data/commaai/destinationChunk_5_99c94dc769b5d96e_2018-07-06--01-15-15_31.t',
#  '../../data/commaai/destinationChunk_3_99c94dc769b5d96e_2018-05-05--11-09-01_14.t',
#  '../../data/commaai/destinationChunk_5_99c94dc769b5d96e_2018-07-05--10-05-06_28.t',
#  '../../data/commaai/destinationChunk_5_99c94dc769b5d96e_2018-07-05--10-05-06_27.t',
#  '../../data/commaai/destinationChunk_3_99c94dc769b5d96e_2018-05-05--11-09-01_15.t',
#  '../../data/commaai/destinationChunk_5_99c94dc769b5d96e_2018-07-04--00-20-19_15.t',
#  '../../data/commaai/destinationChunk_3_99c94dc769b5d96e_2018-05-05--11-09-01_11.t',
#  '../../data/commaai/destinationChunk_5_99c94dc769b5d96e_2018-07-05--10-05-06_35.t',
#  '../../data/commaai/destinationChunk_5_99c94dc769b5d96e_2018-07-04--00-20-19_13.t',
#  '../../data/commaai/destinationChunk_5_99c94dc769b5d96e_2018-07-05--10-05-06_33.t',
#  '../../data/commaai/destinationChunk_5_99c94dc769b5d96e_2018-07-04--00-20-19_12.t',
#  '../../data/commaai/destinationChunk_3_99c94dc769b5d96e_2018-05-05--11-09-01_12.t',
#  '../../data/commaai/destinationChunk_5_99c94dc769b5d96e_2018-07-04--00-20-19_14.t',
#  '../../data/commaai/destinationChunk_3_99c94dc769b5d96e_2018-05-05--11-09-01_17.t',
#  '../../data/commaai/destinationChunk_5_99c94dc769b5d96e_2018-07-04--00-20-19_10.t',
#  '../../data/commaai/destinationChunk_5_99c94dc769b5d96e_2018-07-04--00-20-19_18.t',
#  '../../data/commaai/destinationChunk_5_99c94dc769b5d96e_2018-07-04--00-20-19_16.t',
#  '../../data/commaai/destinationChunk_3_99c94dc769b5d96e_2018-05-05--11-09-01_16.t',
#  '../../data/commaai/destinationChunk_3_99c94dc769b5d96e_2018-05-05--11-09-01_8.t',
#  '../../data/commaai/destinationChunk_5_99c94dc769b5d96e_2018-07-04--00-20-19_9.t',
#  '../../data/commaai/destinationChunk_3_99c94dc769b5d96e_2018-05-05--11-09-01_9.t',
#  '../../data/commaai/destinationChunk_3_99c94dc769b5d96e_2018-05-05--11-09-01_10.t',
#  '../../data/commaai/destinationChunk_5_99c94dc769b5d96e_2018-07-04--00-20-19_17.t',
#  '../../data/commaai/destinationChunk_3_99c94dc769b5d96e_2018-05-05--11-09-01_6.t',
#  '../../data/commaai/destinationChunk_2_b0c9d2329ad1606b_2018-10-19--22-01-05_9.t',
#  '../../data/commaai/destinationChunk_5_99c94dc769b5d96e_2018-07-04--00-20-19_8.t',
#  '../../data/commaai/destinationChunk_3_99c94dc769b5d96e_2018-05-05--11-09-01_5.t',
#  '../../data/commaai/destinationChunk_3_99c94dc769b5d96e_2018-05-03--08-13-12_12.t',
#  '../../data/commaai/destinationChunk_3_99c94dc769b5d96e_2018-05-03--08-13-12_22.t',
#  '../../data/commaai/destinationChunk_3_99c94dc769b5d96e_2018-05-05--11-09-01_13.t',
#  '../../data/commaai/destinationChunk_2_b0c9d2329ad1606b_2018-10-19--22-01-05_6.t',
#  '../../data/commaai/destinationChunk_2_b0c9d2329ad1606b_2018-10-19--22-01-05_10.t',
#  '../../data/commaai/destinationChunk_3_99c94dc769b5d96e_2018-05-05--11-09-01_7.t',
#  '../../data/commaai/destinationChunk_3_99c94dc769b5d96e_2018-05-03--08-13-12_24.t',
#  '../../data/commaai/destinationChunk_3_99c94dc769b5d96e_2018-05-03--08-13-12_9.t',
#  '../../data/commaai/destinationChunk_2_b0c9d2329ad1606b_2018-10-19--22-01-05_11.t',
#  '../../data/commaai/destinationChunk_3_99c94dc769b5d96e_2018-05-03--08-13-12_18.t',
#  '../../data/commaai/destinationChunk_2_b0c9d2329ad1606b_2018-09-15--17-50-36_75.t',
#  '../../data/commaai/destinationChunk_3_99c94dc769b5d96e_2018-05-03--08-13-12_8.t',
#  '../../data/commaai/destinationChunk_2_b0c9d2329ad1606b_2018-09-15--17-50-36_77.t',
#  '../../data/commaai/destinationChunk_2_b0c9d2329ad1606b_2018-09-15--17-50-36_76.t',
#  '../../data/commaai/destinationChunk_3_99c94dc769b5d96e_2018-05-03--08-13-12_15.t',
#  '../../data/commaai/destinationChunk_3_99c94dc769b5d96e_2018-05-03--08-13-12_10.t',
#  '../../data/commaai/destinationChunk_3_99c94dc769b5d96e_2018-05-05--11-09-01_18.t',
#  '../../data/commaai/destinationChunk_2_b0c9d2329ad1606b_2018-09-15--17-50-36_74.t',
#  '../../data/commaai/destinationChunk_2_b0c9d2329ad1606b_2018-10-19--22-01-05_4.t',
#  '../../data/commaai/destinationChunk_3_99c94dc769b5d96e_2018-05-02--20-07-13_2.t',
#  '../../data/commaai/destinationChunk_2_b0c9d2329ad1606b_2018-10-19--22-01-05_7.t',
#  '../../data/commaai/destinationChunk_3_99c94dc769b5d96e_2018-05-02--20-07-13_3.t',
#  '../../data/commaai/destinationChunk_5_99c94dc769b5d96e_2018-07-05--19-49-34_9.t',
#  '../../data/commaai/destinationChunk_5_99c94dc769b5d96e_2018-07-05--19-49-34_14.t',
#  '../../data/commaai/destinationChunk_5_99c94dc769b5d96e_2018-07-05--16-30-16_15.t',
#  '../../data/commaai/destinationChunk_5_99c94dc769b5d96e_2018-07-05--19-49-34_16.t',
#  '../../data/commaai/destinationChunk_5_99c94dc769b5d96e_2018-07-05--16-30-16_4.t',
#  '../../data/commaai/destinationChunk_2_b0c9d2329ad1606b_2018-10-19--22-01-05_8.t',
#  '../../data/commaai/destinationChunk_2_b0c9d2329ad1606b_2018-10-19--22-01-05_12.t',
#  '../../data/commaai/destinationChunk_5_99c94dc769b5d96e_2018-07-05--19-49-34_17.t',
#  '../../data/commaai/destinationChunk_2_b0c9d2329ad1606b_2018-10-19--22-01-05_5.t',
#  '../../data/commaai/destinationChunk_5_99c94dc769b5d96e_2018-07-05--19-49-34_10.t',
#  '../../data/commaai/destinationChunk_5_99c94dc769b5d96e_2018-07-05--16-30-16_9.t',
#  '../../data/commaai/destinationChunk_5_99c94dc769b5d96e_2018-07-05--19-49-34_19.t',
#  '../../data/commaai/destinationChunk_5_99c94dc769b5d96e_2018-07-05--19-49-34_20.t',
#  '../../data/commaai/destinationChunk_5_99c94dc769b5d96e_2018-07-05--16-30-16_13.t',
#  '../../data/commaai/destinationChunk_5_99c94dc769b5d96e_2018-07-05--16-30-16_16.t',
#  '../../data/commaai/destinationChunk_5_99c94dc769b5d96e_2018-07-05--16-30-16_6.t',
#  '../../data/commaai/destinationChunk_5_99c94dc769b5d96e_2018-07-05--16-30-16_12.t',
#  '../../data/commaai/destinationChunk_5_99c94dc769b5d96e_2018-07-05--19-49-34_7.t',
#  '../../data/commaai/destinationChunk_5_99c94dc769b5d96e_2018-07-05--19-49-34_21.t',
#  '../../data/commaai/destinationChunk_5_99c94dc769b5d96e_2018-07-05--19-49-34_15.t',
#  '../../data/commaai/destinationChunk_5_99c94dc769b5d96e_2018-07-05--16-30-16_5.t',
#  '../../data/commaai/destinationChunk_5_99c94dc769b5d96e_2018-07-05--19-49-34_23.t',
#  '../../data/commaai/destinationChunk_5_99c94dc769b5d96e_2018-07-05--16-30-16_17.t',
#  '../../data/commaai/destinationChunk_5_99c94dc769b5d96e_2018-07-05--16-30-16_7.t',
#  '../../data/commaai/destinationChunk_5_99c94dc769b5d96e_2018-07-06--12-32-39_12.t',
#  '../../data/commaai/destinationChunk_5_99c94dc769b5d96e_2018-07-05--19-49-34_12.t',
#  '../../data/commaai/destinationChunk_5_99c94dc769b5d96e_2018-07-05--19-49-34_11.t',
#  '../../data/commaai/destinationChunk_5_99c94dc769b5d96e_2018-07-06--12-32-39_24.t',
#  '../../data/commaai/destinationChunk_5_99c94dc769b5d96e_2018-07-05--19-49-34_18.t',
#  '../../data/commaai/destinationChunk_5_99c94dc769b5d96e_2018-07-05--19-49-34_13.t',
#  '../../data/commaai/destinationChunk_5_99c94dc769b5d96e_2018-07-06--12-32-39_21.t',
#  '../../data/commaai/destinationChunk_5_99c94dc769b5d96e_2018-07-05--16-30-16_19.t',
#  '../../data/commaai/destinationChunk_3_99c94dc769b5d96e_2018-05-03--08-13-12_16.t',
#  '../../data/commaai/destinationChunk_5_99c94dc769b5d96e_2018-07-05--16-30-16_8.t',
#  '../../data/commaai/destinationChunk_3_99c94dc769b5d96e_2018-05-03--08-13-12_19.t',
#  '../../data/commaai/destinationChunk_3_99c94dc769b5d96e_2018-05-03--08-13-12_11.t',
#  '../../data/commaai/destinationChunk_5_99c94dc769b5d96e_2018-07-05--19-49-34_22.t',
#  '../../data/commaai/destinationChunk_5_99c94dc769b5d96e_2018-07-06--12-32-39_10.t',
#  '../../data/commaai/destinationChunk_5_99c94dc769b5d96e_2018-07-05--19-49-34_8.t',
#  '../../data/commaai/destinationChunk_5_99c94dc769b5d96e_2018-07-05--16-30-16_21.t',
#  '../../data/commaai/destinationChunk_3_99c94dc769b5d96e_2018-05-03--08-13-12_17.t',
#  '../../data/commaai/destinationChunk_5_99c94dc769b5d96e_2018-07-05--16-30-16_11.t',
#  '../../data/commaai/destinationChunk_5_99c94dc769b5d96e_2018-07-06--12-32-39_25.t',
#  '../../data/commaai/destinationChunk_3_99c94dc769b5d96e_2018-05-03--08-13-12_20.t',
#  '../../data/commaai/destinationChunk_3_99c94dc769b5d96e_2018-05-03--08-13-12_13.t',
#  '../../data/commaai/destinationChunk_5_99c94dc769b5d96e_2018-07-06--12-32-39_16.t',
#  '../../data/commaai/destinationChunk_3_99c94dc769b5d96e_2018-05-03--08-13-12_21.t',
#  '../../data/commaai/destinationChunk_5_99c94dc769b5d96e_2018-07-05--16-30-16_10.t',
#  '../../data/commaai/destinationChunk_3_99c94dc769b5d96e_2018-05-03--08-13-12_14.t',
#  '../../data/commaai/destinationChunk_5_99c94dc769b5d96e_2018-07-06--12-32-39_17.t',
#  '../../data/commaai/destinationChunk_5_99c94dc769b5d96e_2018-07-06--12-32-39_15.t',
#  '../../data/commaai/destinationChunk_3_99c94dc769b5d96e_2018-05-03--08-13-12_23.t',
#  '../../data/commaai/destinationChunk_5_99c94dc769b5d96e_2018-07-05--16-30-16_3.t',
#  '../../data/commaai/destinationChunk_5_99c94dc769b5d96e_2018-07-05--16-30-16_20.t',
#  '../../data/commaai/destinationChunk_5_99c94dc769b5d96e_2018-07-05--16-30-16_18.t',
#  '../../data/commaai/destinationChunk_5_99c94dc769b5d96e_2018-07-05--16-30-16_14.t',
#  '../../data/commaai/destinationChunk_5_99c94dc769b5d96e_2018-07-06--12-32-39_26.t',
#  '../../data/commaai/destinationChunk_5_99c94dc769b5d96e_2018-07-06--12-32-39_29.t',
#  '../../data/commaai/destinationChunk_5_99c94dc769b5d96e_2018-07-06--12-32-39_27.t',
#  '../../data/commaai/destinationChunk_5_99c94dc769b5d96e_2018-07-03--10-35-30_36.t',
#  '../../data/commaai/destinationChunk_5_99c94dc769b5d96e_2018-07-06--12-32-39_13.t',
#  '../../data/commaai/destinationChunk_5_99c94dc769b5d96e_2018-07-03--10-35-30_29.t',
#  '../../data/commaai/destinationChunk_5_99c94dc769b5d96e_2018-07-06--12-32-39_9.t',
#  '../../data/commaai/destinationChunk_5_99c94dc769b5d96e_2018-07-06--12-32-39_18.t',
#  '../../data/commaai/destinationChunk_2_b0c9d2329ad1606b_2018-09-24--12-49-08_31.t',
#  '../../data/commaai/destinationChunk_5_99c94dc769b5d96e_2018-07-06--12-32-39_28.t',
#  '../../data/commaai/destinationChunk_5_99c94dc769b5d96e_2018-07-06--12-32-39_19.t',
#  '../../data/commaai/destinationChunk_5_99c94dc769b5d96e_2018-07-06--12-32-39_14.t',
#  '../../data/commaai/destinationChunk_2_b0c9d2329ad1606b_2018-09-24--12-49-08_28.t',
#  '../../data/commaai/destinationChunk_5_99c94dc769b5d96e_2018-07-03--10-35-30_39.t',
#  '../../data/commaai/destinationChunk_5_99c94dc769b5d96e_2018-07-06--12-32-39_11.t',
#  '../../data/commaai/destinationChunk_2_b0c9d2329ad1606b_2018-09-24--12-49-08_32.t',
#  '../../data/commaai/destinationChunk_5_99c94dc769b5d96e_2018-07-06--12-32-39_23.t',
#  '../../data/commaai/destinationChunk_2_b0c9d2329ad1606b_2018-09-24--12-49-08_34.t',
#  '../../data/commaai/destinationChunk_5_99c94dc769b5d96e_2018-07-03--10-35-30_28.t',
#  '../../data/commaai/destinationChunk_5_99c94dc769b5d96e_2018-07-06--12-32-39_22.t',
#  '../../data/commaai/destinationChunk_5_99c94dc769b5d96e_2018-07-03--10-35-30_30.t',
#  '../../data/commaai/destinationChunk_2_b0c9d2329ad1606b_2018-09-24--12-49-08_33.t',
#  '../../data/commaai/destinationChunk_5_99c94dc769b5d96e_2018-07-03--10-35-30_35.t',
#  '../../data/commaai/destinationChunk_2_b0c9d2329ad1606b_2018-09-24--12-49-08_29.t',
#  '../../data/commaai/destinationChunk_2_b0c9d2329ad1606b_2018-09-24--12-49-08_27.t',
#  '../../data/commaai/destinationChunk_5_99c94dc769b5d96e_2018-07-03--10-35-30_27.t',
#  '../../data/commaai/destinationChunk_5_99c94dc769b5d96e_2018-07-03--10-35-30_33.t',
#  '../../data/commaai/destinationChunk_5_99c94dc769b5d96e_2018-07-03--10-35-30_38.t',
#  '../../data/commaai/destinationChunk_5_99c94dc769b5d96e_2018-07-03--10-35-30_34.t',
#  '../../data/commaai/destinationChunk_5_99c94dc769b5d96e_2018-07-03--10-35-30_37.t',
#  '../../data/commaai/destinationChunk_5_99c94dc769b5d96e_2018-07-06--18-18-36_6.t',
#  '../../data/commaai/destinationChunk_5_99c94dc769b5d96e_2018-07-06--18-18-36_9.t',
#  '../../data/commaai/destinationChunk_5_99c94dc769b5d96e_2018-07-03--10-35-30_31.t',
#  ...]
