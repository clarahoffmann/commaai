# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import imageio
import matplotlib.pyplot as plt
import cv2

# %%
path0 = '../../../data/commaai/train_bags_2/0/angles_filename.csv'
path1 = '../../../data/commaai/train_bags_2/1/angles_filename.csv'
path2 = '../../../data/commaai/train_bags_2/2/angles_filename.csv'
path3 = '../../../data/commaai/train_bags_2/3/angles_filename.csv'
path4 = '../../../data/commaai/train_bags_2/4/angles_filename.csv'
path5 = '../../../data/commaai/train_bags_2/5/angles_filename.csv'
path6 = '../../../data/commaai/train_bags_2/6/angles_filename.csv'
df0 = pd.read_csv(path0, header = None)
df0.columns = ['filename', 'angle', 'tr_angle']
df1 = pd.read_csv(path1, header = None)
df1.columns = ['filename', 'angle', 'tr_angle']
df2 = pd.read_csv(path2, header = None)
df2.columns = ['filename', 'angle', 'tr_angle']
df3 = pd.read_csv(path3, header = None)
df3.columns = ['filename', 'angle', 'tr_angle']
df4 = pd.read_csv(path4, header = None)
df4.columns = ['filename', 'angle', 'tr_angle']
df5 = pd.read_csv(path5, header = None)
df5.columns = ['filename', 'angle', 'tr_angle']

df = df0.append(df1).append(df2).append(df3).append(df4).append(df5)
df = df.reset_index()
df = df.loc[:, ['filename','angle']]

# %%
def change_brightness(img, value=30):
    hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
    h, s, v = cv2.split(hsv)
    v = cv2.add(v,value)
    v[v > 255] = 255
    v[v < 0] = 0
    final_hsv = cv2.merge((h, s, v))
    img = cv2.cvtColor(final_hsv, cv2.COLOR_HSV2BGR)
    return img

# %% [markdown]
# ## Example 1

# %%
im = imageio.imread(str('../../../data/commaai/train_bags_2/0/2_1079run1.png'))
label = float(df.loc[df['filename'] == 'commaai/train_bags_2/0/2_1079run1.png', 'angle'])
label = label
figure, ax = plt.figure(), plt.gca()
#circle1 = plt.Circle((0.2, 0.5), 0.5, color='r')
#ax.add_patch(circle1)
#plt.imshow(img)
ax.imshow(change_brightness(im, value = 70)) #change_brightness(, value=10))
a_rad = label / 180. * np.pi + np.pi / 2
c, r = (582,873), 300 #center, radius
t = (c[0] + int(np.cos(a_rad) * r), c[1] - int(np.sin(a_rad) * r))
plt.plot((c[0], t[0]), (c[1] , t[1] + 30), 'r', alpha = 1)
plt.gca().add_artist(plt.Circle(c, r, edgecolor='dodgerblue', fill = 0))
plt.text(c[0] - 550 , c[1] - 800, 'true steering angle: {:0.1f}$^\circ$'.format(label), color='w')
ax.get_xaxis().set_visible(False)
ax.get_yaxis().set_visible(False)
ax.axis('off')
figure.tight_layout()
figure.savefig('image_road_angle.png', format='png', dpi=300)

# %%
figure, ax = plt.figure(), plt.gca()
ax.imshow(change_brightness(im, value = 70)) 
ax.get_xaxis().set_visible(False)
ax.get_yaxis().set_visible(False)
ax.axis('off')
plt.tight_layout()
figure.savefig('image_road.pdf', format='pdf', dpi=300)

# %% [markdown]
# ## Example 2

# %%
im = imageio.imread(str('../../../data/commaai/train_bags_2/2/55_1075run1.png'))
label = float(df.loc[df['filename'] == 'commaai/train_bags_2/2/55_1075run1.png', 'angle'])
figure, ax = plt.figure(), plt.gca()
#circle1 = plt.Circle((0.2, 0.5), 0.5, color='r')
#ax.add_patch(circle1)
#plt.imshow(img)
ax.imshow(change_brightness(im, value=15))
a_rad = label / 180. * np.pi + np.pi / 2
c, r = (582,873), 300 #center, radius
t = (c[0] + int(np.cos(a_rad) * r), c[1] - int(np.sin(a_rad) * r))
plt.plot((c[0], t[0]), (c[1] , t[1] + 30), 'r', alpha = 1)
plt.gca().add_artist(plt.Circle(c, r, edgecolor='dodgerblue', fill = 0))
plt.text(c[0] - 550 , c[1] - 800, 'true steering angle: {:0.1f}$^\circ$'.format(label), color='w')
ax.get_xaxis().set_visible(False)
ax.get_yaxis().set_visible(False)
ax.axis('off')
plt.tight_layout()
figure.savefig('example_no_dens_2.png', format='png', dpi=300)

# %% [markdown]
# ## Example 3

# %%
im = imageio.imread(str('../../../data/commaai/train_bags_2/1/27_1078run1.png')) 
label = float(df.loc[df['filename'] == 'commaai/train_bags_2/1/27_1078run1.png', 'angle'])
figure, ax = plt.figure(), plt.gca()
#circle1 = plt.Circle((0.2, 0.5), 0.5, color='r')
#ax.add_patch(circle1)
#plt.imshow(img)
ax.imshow(change_brightness(im, value=70))
a_rad = label / 180. * np.pi + np.pi / 2
c, r = (582,873), 300 #center, radius
t = (c[0] + int(np.cos(a_rad) * r), c[1] - int(np.sin(a_rad) * r))
plt.plot((c[0], t[0]), (c[1] , t[1] + 30), 'r', alpha = 1)
plt.gca().add_artist(plt.Circle(c, r, edgecolor='dodgerblue', fill = 0))
plt.text(c[0] - 550 , c[1] - 800, 'true steering angle: {:0.1f}$^\circ$'.format(label), color='w')
ax.get_xaxis().set_visible(False)
ax.get_yaxis().set_visible(False)
plt.tight_layout()
ax.axis('off')
plt.tight_layout()
figure.savefig('example_no_dens_3.png', format='png', dpi=300)

# %%
df[abs(df['angle']) < 10]
